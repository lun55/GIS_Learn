# %%
import pandas as pd
import datetime

# %%
tem = pd.read_csv(r"C:\Users\LMQ\Desktop\CHM00053863.csv")
tem
# Out:
#            STATION        DATE  LATITUDE  LONGITUDE  ELEVATION        NAME  \
# 0      CHM00053863  1954-01-01    37.033    111.917      745.0  JIEXIU, CH
# 1      CHM00053863  1954-01-02    37.033    111.917      745.0  JIEXIU, CH
# 2      CHM00053863  1954-01-03    37.033    111.917      745.0  JIEXIU, CH
# 3      CHM00053863  1954-01-04    37.033    111.917      745.0  JIEXIU, CH
# 4      CHM00053863  1954-01-05    37.033    111.917      745.0  JIEXIU, CH
# ...            ...         ...       ...        ...        ...         ...
# 25482  CHM00053863  2023-11-05    37.033    111.917      745.0  JIEXIU, CH
# 25483  CHM00053863  2023-11-06    37.033    111.917      745.0  JIEXIU, CH
# 25484  CHM00053863  2023-11-07    37.033    111.917      745.0  JIEXIU, CH
# 25485  CHM00053863  2023-11-08    37.033    111.917      745.0  JIEXIU, CH
# 25486  CHM00053863  2023-11-09    37.033    111.917      745.0  JIEXIU, CH
#
# ...

# %%
tem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25487 entries, 0 to 25486
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   STATION          25487 non-null  object
#  1   DATE             25487 non-null  object
#  2   LATITUDE         25487 non-null  float64
#  3   LONGITUDE        25487 non-null  float64
#  4   ELEVATION        25487 non-null  float64
#  5   NAME             25487 non-null  object
#  6   PRCP             23655 non-null  float64
#  7   PRCP_ATTRIBUTES  23655 non-null  object
#  8   SNWD             21 non-null     float64
#  9   SNWD_ATTRIBUTES  21 non-null     object
#  10  TMAX             25467 non-null  float64
#  11  TMAX_ATTRIBUTES  25467 non-null  object
#  12  TMIN             24598 non-null  float64
#  13  TMIN_ATTRIBUTES  24598 non-null  object
#  14  TAVG             25483 non-null  float64
#  15  TAVG_ATTRIBUTES  25483 non-null  object
# dtypes: float64(8), object(8)
# ...

# %%
tem = tem[['DATE','PRCP','TMAX','TAVG']]
tem
# Out:
#             DATE  PRCP  TMAX  TAVG
# 21185 2012-01-02   0.0   0.3  -2.5
# 21186 2012-01-03   0.0  -2.7  -6.3
# 21187 2012-01-04   0.0  -0.2  -7.3
# 21188 2012-01-05   0.0  -0.8  -9.5
# 21189 2012-01-06   0.0  -0.1  -8.3
# ...          ...   ...   ...   ...
# 25480 2023-11-03   0.0  24.0  12.4
# 25483 2023-11-06   0.0  11.0   5.3
# 25484 2023-11-07   0.0  14.5   6.6
# 25485 2023-11-08   0.0  19.0  10.3
# 25486 2023-11-09   0.0  19.0   6.8
#
# [1593 rows x 4 columns]

# %%
tem['DATE'] = pd.to_datetime(tem['DATE'])
tem['TMAX'] = tem['TMAX']*10
tem['TAVG'] = tem['TAVG']*10
tem.info(),tem
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25487 entries, 0 to 25486
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    25487 non-null  datetime64[ns]
#  1   PRCP    23655 non-null  float64
#  2   TMAX    25467 non-null  float64
#  3   TAVG    25483 non-null  float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 796.6 KB
# C:\Users\LMQ\AppData\Local\Temp\ipykernel_36236\3561427993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tem['DATE'] = pd.to_datetime(tem['DATE'])
# C:\Users\LMQ\AppData\Local\Temp\ipykernel_36236\3561427993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
tem = tem[tem['PRCP']==0]
tem = tem[tem['DATE']>='2012']
tem
# Out:
#             DATE  PRCP  TMAX  TAVG
# 21185 2012-01-02   0.0   0.3  -2.5
# 21186 2012-01-03   0.0  -2.7  -6.3
# 21187 2012-01-04   0.0  -0.2  -7.3
# 21188 2012-01-05   0.0  -0.8  -9.5
# 21189 2012-01-06   0.0  -0.1  -8.3
# ...          ...   ...   ...   ...
# 25480 2023-11-03   0.0  24.0  12.4
# 25483 2023-11-06   0.0  11.0   5.3
# 25484 2023-11-07   0.0  14.5   6.6
# 25485 2023-11-08   0.0  19.0  10.3
# 25486 2023-11-09   0.0  19.0   6.8
#
# [1593 rows x 4 columns]

# %%
tem.to_csv(r"C:\Users\LMQ\Desktop\shanxi.csv")

# %%
fire = pd.read_csv(r"C:\Users\LMQ\Desktop\viirs_alerts__count.csv")
fire.sort_values(by='alert__year',ascending=True,inplace=True)
fire
# Out:
#     alert__week  alert__year  alert__count confidence__cat
# 86           14         2012             2               h
# 82           46         2012             1               h
# 85           41         2012             2               h
# 84           42         2012             4               h
# 83           44         2012             1               h
# ..          ...          ...           ...             ...
# 4            26         2023             1               h
# 3            41         2023             3               h
# 2            42         2023             8               h
# 1            43         2023            10               h
# 0            44         2023             2               h
#
# [87 rows x 4 columns]

# %%
fire_ = fire.groupby(by='alert__year',as_index = False).agg({'alert__count':'sum'})
fire_
# Out:
#     alert__year  alert__count
# 0          2012            10
# 1          2013            61
# 2          2014            24
# 3          2015            29
# 4          2016            23
# 5          2017            10
# 6          2018            83
# 7          2019            52
# 8          2020            12
# 9          2021             6
# 10         2022             1
# 11         2023            26

# %%
tem['year'] = pd.to_datetime(tem['DATE']).dt.year
tem['count'] = tem['TMAX'].apply(lambda x:1 if x >30 else 0)
tem_y = tem.groupby(by='year',as_index = False).agg({'count':'sum'})
tem_y
# Out:
#     year  count
# 0   2012     32
# 1   2013      9
# 2   2014      5
# 3   2015      7
# 4   2016      2
# 5   2017      5
# 6   2018      5
# 7   2019      6
# 8   2020     56
# 9   2021     74
# 10  2022     70
# 11  2023     75

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(tem_y['year'],tem_y['count'])
plt.title('tem')

plt.plot(fire_['alert__year'],fire_['alert__count'])
plt.title('fire_')
# Out:
# Text(0.5, 1.0, 'fire_')
